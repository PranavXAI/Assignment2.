# %% [markdown]
# ***Assignment 2***

# %% [markdown]
# 1. What are data structures, and why are they important?
#
#
# -> A way of organizing and storing data so that it can be accessed and manipulated efficiently
# why it is importanat :
# Efficiancy,optimized resourse use, Real world application,Scalability

# %% [markdown]
# 2. Explain the difference between mutable and immutable data types with examples?
#
# -> Mutable data type is changble or updatable for example list, dictionary, set
# immutable data type is unchagable for example float , string,list, byte ,tuples

# %% [markdown]
# 3.What are the main differences between lists and tuples in Python?
#
# ->LIST:
#  list are mutable , list are ordered collection of items ,can store any data type
#
#
#  TUPLE:
#  Tuple are basically data type or data structure which are denoted with round ()brackets
#  It has hetergen values
#  ex - int ,string, float

# %% [markdown]
# 4.Describe how dictionaries store data?
#
# -> Dictionry it is a data structure that stores data as a key value pair
# key are unique and immutable

# %% [markdown]
# 5.Why might you use a set instead of a list in Python?
#
# -> Reasons to Use a Set Instead of a List
#
# No Duplicates Allowed
#
# A set automatically removes duplicates.

# %% [markdown]
# 6,What is a string in Python, and how is it different from a list?
#
# -> A string is a sequence of characters enclosed in single quotes ('), double quotes ("), or triple quotes (''' """).
#
# Strings are immutable, meaning once created, their contents cannot be changed.

# %% [markdown]
# 7.How do tuples ensure data integrity in Python?
#
# -> A tuple is an ordered collection of elements, similar to a list, but immutable (cannot be changed after creation).
# This immutability is what helps ensure data integrity.

# %% [markdown]
# 8.What is a hash table, and how does it relate to dictionaries in Python?
#
# -> A hash table is a data structure that stores data in key–value pairs and uses a hash function to map each key to an index in an underlying array (called a bucket).
#
# In Python, a dictionary (dict) is implemented using a hash table.
#
# Each dictionary entry = key → hash function → index → value.

# %% [markdown]
# 9.Can lists contain different data types in Python?
#
# -> yes
# In Python, lists are very flexible and can contain elements of different data types in the same list.

# %% [markdown]
# 10.Explain why strings are immutable in Python?
#
# -> 1. Memory Efficiency (String Interning)
#
# Python often reuses string objects (called string interning) to save memory.
#
# If strings were mutable, changing one variable co

# %% [markdown]
# 11.What advantages do dictionaries offer over lists for certain tasks?
#
# -> Fast Lookups (O(1) vs O(n))
#
# Dictionaries use a hash table, so finding a value by key is constant time (O(1)) on average.
#
# Lists require searching element by element (O(n)).
# . Key–Value Mapping
#
# Dictionaries allow you to associate a meaningful key with a value.
#
# Lists only allow index-based access (0, 1, 2…).

# %% [markdown]
# 12.Describe a scenario where using a tuple would be preferable over a list?
#
# -> tuples are immutable, they are best used when you need data that should not change throughout the program.

# %% [markdown]
# 13. How do sets handle duplicate values in Python?
#
# -> A set in Python is an unordered collection of unique elements.
# This means duplicates are automatically removed when you create a set or add elements to it.

# %% [markdown]
# 14. How does the “in” keyword work differently for lists and dictionaries?
#
# -> Checks whether a value exists in the list.
#
# Search is linear (O(n)), because Python has to check each element one by one.
#
#
# “in” with Dictionaries
#
# By default, in checks for keys, not values.
#
# Search is very fast (O(1)), because dictionaries use a hash table.

# %% [markdown]
# 15.Can you modify the elements of a tuple? Explain why or why not?
#
# -> No, you cannot modify the elements of a tuple directly.
#
# This is because tuples are immutable in Python. Once a tuple is created, its elements cannot be changed, added, or removed.

# %% [markdown]
# 16.What is a nested dictionary, and give an example of its use case?
#
# -> What is a Nested Dictionary?
#
# A nested dictionary is a dictionary where one or more values are themselves dictionaries.
# This allows you to store complex, hierarchical data in a structured way.
#
# student = {
#     "Alice": {"age": 21, "course": "CS", "grades": {"Math": 95, "Physics": 90}},
#     "Bob": {"age": 22, "course": "EE", "grades": {"Math": 88, "Physics": 92}}
# }

# %% [markdown]
# 17.Describe the time complexity of accessing elements in a dictionary?
#
# -> Python dictionaries are implemented using hash tables, which is why they are very fast for key-based access.

# %% [markdown]
# 18. In what situations are lists preferred over dictionaries?
#
# ->Although dictionaries are fast and flexible, lists are better suited for certain situations:
#
# 1. Ordered Collection
#
# Lists maintain the order of elements.
#
# If the order of items matters (like a sequence of steps, a queue, or a timeline), lists are better.
#
# Duplicate Values Are Allowed
#
# Lists allow duplicates, dictionaries cannot have duplicate keys

# %% [markdown]
# 19.  Why are dictionaries considered unordered, and how does that affect data retrieval?
#
# -> In Python, dictionaries store data as key-value pairs using a hash table.
#
# The position of items in memory is determined by the hash of the keys, not by the order they were inserted (prior to Python 3.7).
#
# Therefore, dictionaries did not preserve order in older versions of Python.

# %% [markdown]
# 20.  Explain the difference between a list and a dictionary in terms of data retrieval. ?
#
# ->1. Lists
#
# Access by index: You retrieve elements using their position in the list.
#
# Time complexity: Accessing by index is O(1) (fast), but searching for a value is O(n) (linear scan).
#
# 2. Dictionaries
#
# Access by key: You retrieve elements using a key rather than a position.
#
# Time complexity: Access by key is O(1) on average, because dictionaries use a hash table.

# %% [markdown]
# ## PRACTICAL QUESTON

# %%
# Write a code to create a string with your name and print it
name = "Pranav Sontakke"
print(name)
# Out:
# Pranav Sontakke

# %%
#Write a code to find the length of the string "Hello World"
text = "Hello World"
length = len(text)
print("Length of the string:", length)
# Out:
# Length of the string: 11

# %%
# Write a code to slice the first 3 characters from the string "Python Programming"
text = "Python Programming"
sliced_text = text[:3]
print("First 3 characters:", sliced_text)
# Out:
# First 3 characters: Pyt

# %%
# Write a code to convert the string "hello" to uppercase
text = "hello"
uppercase_text = text.upper()
print("Uppercase string:", uppercase_text)
# Out:
# Uppercase string: HELLO

# %%
# Write a code to replace the word "apple" with "orange" in the string "I like apple"
text = "I like apple"
new_text = text.replace("apple", "orange")
print(new_text)
# Out:
# I like orange

# %%
# Write a code to create a list with numbers 1 to 5 and print it

# %%
# Write a code to create a list with numbers 1 to 5 and print it
my_list = [1, 2, 3, 4, 5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
my_list = [1, 2, 3, 4, 5]
my_list.remove(3)
print(my_list)
# Out:
# [1, 2, 4, 5]

# %%
# Write a code to append the number 10 to the list [1, 2, 3, 4]
my_list = [1, 2, 3, 4]
my_list.append(10)
print(my_list)
# Out:
# [1, 2, 3, 4, 10]

# %%
#Write a code to access the second element in the list ['a', 'b', 'c', 'd']
my_list = ['a', 'b', 'c', 'd']
second_element = my_list[1]
print("The second element is:", second_element)
# Out:
# The second element is: b

# %%
# Write a code to reverse the list [10, 20, 30, 40, 50].
my_list = [10, 20, 30, 40, 50]
my_list.reverse()
print(my_list)
# Out:
# [50, 40, 30, 20, 10]

# %%
# Write a code to create a tuple with the elements 100, 200, 300 and print it.
my_tuple = (100, 200, 300)
print(my_tuple)
# Out:
# (100, 200, 300)

# %%
# Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
my_tuple = ('red', 'green', 'blue', 'yellow')
second_to_last_element = my_tuple[-2]
print("The second-to-last element is:", second_to_last_element)
# Out:
# The second-to-last element is: blue

# %%
# Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
my_tuple = ('dog', 'cat', 'rabbit')
index_of_cat = my_tuple.index("cat")
print("The index of 'cat' is:", index_of_cat)
# Out:
# The index of 'cat' is: 1

# %%
# Write a code to find the minimum number in the tuple (10, 20, 5, 15).
my_tuple = (10, 20, 5, 15)
min_number = min(my_tuple)
print("The minimum number is:", min_number)
# Out:
# The minimum number is: 5

# %%
# Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
fruits_tuple = ('apple', 'banana', 'orange')
if "kiwi" in fruits_tuple:
    print("Kiwi is in the tuple.")
else:
    print("Kiwi is not in the tuple.")
# Out:
# Kiwi is not in the tuple.

# %%
# Write a code to create a set with the elements 'a', 'b', 'c' and print it.
my_set = {'a', 'b', 'c'}
print(my_set)
# Out:
# {'b', 'c', 'a'}

# %%
# Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
my_set = {1, 2, 3, 4, 5}
my_set.clear()
print(my_set)
# Out:
# set()

# %%
# Write a code to remove the element 4 from the set {1, 2, 3, 4}.
my_set = {1, 2, 3, 4}
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 3}

# %%
# Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1.union(set2)
print("Union of the two sets:", union_set)
# Out:
# Union of the two sets: {1, 2, 3, 4, 5}

# %%
# Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
set1 = {1, 2, 3}
set2 = {2, 3, 4}
intersection_set = set1.intersection(set2)
print("Intersection of the two sets:", intersection_set)
# Out:
# Intersection of the two sets: {2, 3}

# %%
# Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
my_dict = {"name": "Alice", "age": 30, "city": "New York"}
print(my_dict)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
# Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
my_dict = {'name': 'John', 'age': 25}
my_dict["country"] = "USA"
print(my_dict)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
# Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
my_dict = {'name': 'Alice', 'age': 30}
name_value = my_dict["name"]
print("The value associated with 'name' is:", name_value)
# Out:
# The value associated with 'name' is: Alice

# %%
# Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
my_dict = {'name': 'Bob', 'age': 22, 'city': 'New York'}
del my_dict["age"]
print(my_dict)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
# Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
my_dict = {'name': 'Alice', 'city': 'Paris'}
if "city" in my_dict:
    print("The key 'city' exists in the dictionary.")
else:
    print("The key 'city' does not exist in the dictionary.")
# Out:
# The key 'city' exists in the dictionary.

# %%
# Write a code to create a list, a tuple, and a dictionary, and print them all.

# Create a list
my_list = [1, 2, 3, 4]
print("List:", my_list)

# Create a tuple
my_tuple = (10, 20, 30)
print("Tuple:", my_tuple)

# Create a dictionary
my_dict = {"name": "Alice", "age": 30}
print("Dictionary:", my_dict)
# Out:
# List: [1, 2, 3, 4]
# Tuple: (10, 20, 30)
# Dictionary: {'name': 'Alice', 'age': 30}

# %%
# Write a code to create a list with strings and print the element at the third index.
my_list = ["apple", "banana", "cherry", "date", "elderberry"]
print("The element at the third index is:", my_list[3])
# Out:
# The element at the third index is: date

# %%
import random

# Create a list of 5 random numbers between 1 and 100
random_numbers = [random.randint(1, 100) for _ in range(5)]
print("Original list:", random_numbers)

# Sort the list in ascending order
random_numbers.sort()

# Print the sorted list
print("Sorted list:", random_numbers)
# Out:
# Original list: [66, 65, 24, 64, 79]
# Sorted list: [24, 64, 65, 66, 79]

# %%
# Write a code to combine two dictionaries into one and print the result.
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}
combined_dict = {**dict1, **dict2}
print(combined_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# Write a code to convert a list of strings into a set.
my_list = ["apple", "banana", "cherry", "apple"]
my_set = set(my_list)
print(my_set)
# Out:
# {'apple', 'banana', 'cherry'}
